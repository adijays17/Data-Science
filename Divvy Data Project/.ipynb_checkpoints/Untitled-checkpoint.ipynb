# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('bike.csv')

# %%
df.head()
# Out:
#    ID  PARK_AREA_ACRES  CTA_BUS_STATIONS  CTA_TRAIN_STATIONS  BIKE_ROUTES  \
# 0   5        998.35328               217                  19    37.260009
# 1  13       1204.28480               152                   6    23.544022
# 2  14       1135.55648               133                   2    21.615016
# 3  15       1108.60416               146                   2    17.309916
# 4  16        955.64416               153                   3    15.953728
#
#    Limited_Business_License  Retail_Food_Establishment  CAPACITY  \
# 0                    419417                     118269        19
# 1                     42998                      27496        19
# 2                     57119                      23273        15
# 3                     31090                      14369        15
# 4                     43002                      19727        11
#
#    PER_CAPITA_INCOME  POPULATION_SQ_MILE ...  PROSTITUTION  PUBLIC_INDECENCY  \
# 0              65526         36691.00331 ...      2.397895          1.386294
# 1              65526         26901.43828 ...      0.693147          0.000000
# 2              65526         27738.26651 ...      1.609438          0.000000
# 3              88669         28008.49477 ...      1.609438          0.000000
# 4              65526         24577.70577 ...      0.693147          0.000000
#
#    PUBLIC_PEACE_VIOLATION   ROBBERY  SEX_OFFENSE  STALKING     THEFT  \
# 0                4.369448  5.752573     3.951244  1.609438  8.269501
# 1                2.564949  4.905275     2.708050  1.098612  7.312553
# 2                2.639057  3.688879     1.098612  1.386294  6.089045
# 3                3.178054  3.891820     1.945910  1.386294  6.171701
# 4                2.302585  5.351858     2.564949  0.000000  7.658700
#
#    WEAPONS_VIOLATION      trips   i
# 0           3.044522  10.092826  33
# 1           0.693147  10.350798  33
# 2           2.397895   9.227001  33
# 3           2.944439   9.279493  33
# 4           2.397895   9.846441  33
#
# [5 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 46 columns):
# ID                                  300 non-null int64
# PARK_AREA_ACRES                     300 non-null float64
# CTA_BUS_STATIONS                    300 non-null int64
# CTA_TRAIN_STATIONS                  300 non-null int64
# BIKE_ROUTES                         300 non-null float64
# Limited_Business_License            300 non-null int64
# Retail_Food_Establishment           300 non-null int64
# CAPACITY                            300 non-null int64
# PER_CAPITA_INCOME                   300 non-null int64
# POPULATION_SQ_MILE                  300 non-null float64
# CBD                                 300 non-null int64
# MINORITY                            300 non-null float64
# EDU                                 300 non-null float64
# ARSON                               300 non-null float64
# ASSAULT                             300 non-null float64
# BATTERY                             300 non-null float64
# BURGLARY                            300 non-null float64
# CONCEALED_CARRY_LICENSE_VIOLATIO    300 non-null float64
# CRIM_SEXUAL_ASSAULT                 300 non-null float64
# CRIMINAL_DAMAGE                     300 non-null float64
# CRIMINAL_TRESPASS                   300 non-null float64
# DECEPTIVE_PRACTICE                  300 non-null float64
# GAMBLING                            300 non-null float64
# HOMICIDE                            300 non-null float64
# HUMAN_TRAFFICKING                   300 non-null float64
# INTERFERENCE_WITH_PUBLIC_OFFICER    300 non-null float64
# INTIMIDATION                        300 non-null float64
# KIDNAPPING                          300 non-null float64
# LIQUOR_LAW_VIOLATION                300 non-null float64
# MOTOR_VEHICLE_THEFT                 300 non-null float64
# NARCOTICS                           300 non-null float64
# NON_CRIMINAL                        300 non-null float64
# OBSCENITY                           300 non-null float64
# OFFENSE_INVOLVING_CHILDREN          300 non-null float64
# OTHER_NARCOTIC_VIOLATION            300 non-null float64
# OTHER_OFFENSE                       300 non-null float64
# PROSTITUTION                        300 non-null float64
# PUBLIC_INDECENCY                    300 non-null float64
# PUBLIC_PEACE_VIOLATION              300 non-null float64
# ROBBERY                             300 non-null float64
# SEX_OFFENSE                         300 non-null float64
# STALKING                            300 non-null float64
# THEFT                               300 non-null float64
# WEAPONS_VIOLATION                   300 non-null float64
# trips                               300 non-null float64
# i                                   300 non-null int64
# dtypes: float64(37), int64(9)
# memory usage: 107.9 KB

# %%
col = df.columns.values.tolist()
for e in col:
    # gca stands for 'get current axis'
    ax = plt.gca()
    df.plot(kind='scatter',x='trips',y=e, color='blue', ax=ax)
    plt.show()

# %%
col = df.columns.values.tolist()
fig, axes = plt.subplots(nrows=2, ncols=2)
for e in col:
    # gca stands for 'get current axis'
    df.plot(kind='scatter',x='trips',y=e, color='blue', ax=axes)
plt.show()
